# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State

import plotly.graph_objs as go
import pandas as pd
from datetime import datetime

import yfinance as yf

# Read data
df = pd.read_csv('../DATA/chilean_stocks.csv', index_col='Date')
df = df.groupby(by=['Ticker', 'Name']).sum().reset_index()[['Ticker','Name']].set_index('Ticker')

available_tickers = []
for tic in df.index:
    available_tickers.append({'label':df.loc[tic]['Name'], 'value':tic})

# Release memory
del df

app = dash.Dash(
    __name__, meta_tags=[{"name": "viewport", "content": "width=device-width"}]
)

available_columns = ['Open', 'High', 'Low', 'Close', 'Volume', 'Pct Change - Close', 'Cummulative Returns']

app.layout = html.Div([
    html.H1('Bolsa de Santiago - Principales Acciones - Dashboard',
            style={'textAlign': 'center'},
           ),
    html.Div([html.H3(html.Label('Seleccionar la Acción')),
            dcc.Dropdown(
                id='ticker-selected',
                options=available_tickers,
                value='LTM.SN',
                multi=True,
                placeholder="Acción",
                clearable=False,
            )
    ],style={'width': '48%', 'display': 'inline-block'},),
    html.Div([html.H3(html.Label('Elija Información a visualizar')),
            dcc.Dropdown(
                id='y-selected',
                options=[{'label': i, 'value': i} for i in available_columns],
                value='Close',
                placeholder="Información a visualizar",
                clearable=False,
            )
    ],style={'width': '48%', 'display': 'inline-block'},),
    html.Div([
        html.H3('Seleccione fecha de inicio y final:'),
        dcc.DatePickerRange(
            id='my_date_picker',
            min_date_allowed=datetime(2018, 1, 1),
            max_date_allowed=datetime.today(),
            start_date=datetime(2020, 1, 1),
            end_date=datetime.today()
        )
    ], style={'display':'inline-block'}),
    html.Div([
        html.Button(
            id='submit-button',
            n_clicks=0,
            children='Submit',
            style={'fontSize':24, 'marginLeft':'30px'}
        ),
    ], style={'display':'inline-block'}),
    # Graph 
    html.Hr(),
    html.Div([dcc.Graph(id='graph-stock',
                        figure={
                            'data': [
                                {'x': [0,0], 'y': [0,0]}
                            ]
                        }),                         
             ],),
    html.Div([dcc.Graph(id='table-stock',
                        figure={
                            'data': [
                                {'x': [0,0], 'y': [0,0]}
                            ]
                        }),                         
             ],),
    html.Hr(),
])

@app.callback(Output('graph-stock', 'figure'),
              [Input('submit-button', 'n_clicks')],
              [State('ticker-selected', 'value'),
               State('y-selected', 'value'),
               State('my_date_picker', 'start_date'),
               State('my_date_picker', 'end_date'),
              ]
             )


def update_graph(n_clicks, tickers, col, start_date, end_date):
    start = datetime.strptime(start_date[:10], '%Y-%m-%d')
    end = datetime.strptime(end_date[:10], '%Y-%m-%d')
    traces = []
    title = ''
    if type(tickers)==str: tickers = [tickers]
    #tickers.append('BOLSASTGO.SN')
    for accion in tickers:
        df_ticker = yf.Ticker(accion)
        # get company name

        try:
            longname = df_ticker.info['longName']
            industry = df_ticker.info['industry']
            payoutRatio = df_ticker.info['payoutRatio']
        except:
            longname = accion
            industry = 'N/A'
            payoutRatio = 0 
        # get historical market data
        df = df_ticker.history(start=start, end=end, interval='1d')
        df['Ticker'] = accion
        df['Name'] = longname
        df['Industry'] = industry
        df['PayoutRatio'] = payoutRatio
        df['Pct Change - Close'] = df.Close.pct_change()
        df['Cummulative Returns'] = ((1 + df['Pct Change - Close']).cumprod() - 1)    

        data = go.Scatter(x = df.index, y=df[col], mode='lines+markers', 
                          name=accion,
                          text=longname, 
                          hovertext=["x", "text", col],
                          hoverinfo=["y"],
                          xaxis='x2',
                          yaxis='y2',
                          marker=dict(symbol = 'pentagon-dot',
                                      opacity = 0.8,
                                      line   = dict(width=2),
                                     ),
                         )
        traces.append(data)
        title = title + accion+'/'
    layout = go.Layout(title = title+' - '+'<b>'+col+'</b>'+'<br>'+'Desde : '+start_date[:10] \
                       + ' Hasta : '+end_date[:10],
                       title_x=0.5,
                       xaxis = dict(title='Fecha'),
                       yaxis = dict(title=col),
                       hovermode="x unified",
                       hoverlabel=dict(bgcolor="white", 
                                       font_size=10, 
                                       font_family="Rockwell"
                                      ),
                       template='presentation',
                       height=600,
                       autosize=True,  
                      )
    fig = go.Figure(data=traces,layout=layout)
    fig.update_xaxes(rangeslider_visible=True,
                     rangeselector=dict(buttons=list([
                         dict(count=1, label="1m", step="month", stepmode="backward"),
                         dict(count=6, label="6m", step="month", stepmode="backward"),
                         dict(count=1, label="YTD", step="year", stepmode="todate"),
                         dict(count=1, label="1y", step="year", stepmode="backward"),
                         dict(count=3, label="3y", step="year", stepmode="backward"),
                         dict(count=5, label="5y", step="year", stepmode="backward"),
                         dict(step="all")])))
    return fig

@app.callback(Output('table-stock', 'figure'),
              [Input('submit-button', 'n_clicks')],
              [State('ticker-selected', 'value'),
               State('y-selected', 'value'),
               State('my_date_picker', 'start_date'),
               State('my_date_picker', 'end_date'),
              ]
             )

def update_table(n_clicks, tickers, col, start_date, end_date):
    start = datetime.strptime(start_date[:10], '%Y-%m-%d')
    end = datetime.strptime(end_date[:10], '%Y-%m-%d')
    df_table = pd.DataFrame()
    if type(tickers)==str: tickers = [tickers]
    #tickers.append('BOLSASTGO.SN')
    for accion in tickers:
        df_ticker = yf.Ticker(accion)
        # get company name
        try:
            longname = df_ticker.info['longName']
            industry = df_ticker.info['industry']
            payoutRatio = df_ticker.info['payoutRatio']
        except:
            longname = accion
            industry = 'N/A'
            payoutRatio = 0 
        # get historical market data
        df = df_ticker.history(start=start, end=end, interval='1d')
        df['Ticker'] = accion
        df['Name'] = longname
        df['Industry'] = industry
        df['PayoutRatio'] = payoutRatio
        df['Pct Change - Close'] = df.Close.pct_change()
        df['Cummulative Returns'] = ((1 + df['Pct Change - Close']).cumprod() - 1)
        df_table = df_table.append(df)
    
    df_table.reset_index(inplace=True)
    df_table.sort_values(["Name", "Date"], axis=0, ascending=False, inplace=True) 
    df_table['Fecha'] = df_table['Date'].apply(lambda x:datetime.strftime(x,'%d/%m/%Y'))
    df_table = df_table[['Fecha','Name','Industry', 'Open', 'High', 'Low', 'Close', 'Volume', 'Pct Change - Close','Cummulative Returns']]
    table = go.Table(header=dict(values=list(df_table.columns),
                                 font=dict(size=10),
                                 #fill_color='paleturquoise',
                                 align='left'),
                     cells=dict(values=[df_table[k].tolist() for k in df_table.columns],
                                align = "left",
                                font=dict(size=10),
                               ),
                    )
    layout = go.Layout(title = 'Detalle de Información - '+'<b>'+col+'<b>', title_x=0.5,)
    fig = go.Figure(data=table, layout=layout)
    
    return fig
              
if __name__ == '__main__':
    app.run_server()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/Jan/2022 13:13:44] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:13:44] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:13:44] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:13:51] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:13:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:14:23] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:14:24] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:15:48] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:15:50] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:16:16] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:16:17] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:16:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [22/Jan/2022 13:16:53] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output, State

import plotly.graph_objs as go
import pandas as pd
from datetime import datetime

import yfinance as yf

# %%
df_ticker = yf.Ticker('LTM.SN')

# %%
df_ticker.info
# Out:
# {'sector': 'Industrials',
#  'fullTimeEmployees': 28701,
#  'longBusinessSummary': 'LATAM Airlines Group S.A., together with its subsidiaries, provides passenger and cargo air transportation services in Peru, Argentina, the United States, Europe, Colombia, Brazil, Ecuador, Chile, the Asia Pacific, and rest of Latin America. The company provides passenger transport services to approximately 111 destinations in 16 countries, as well as cargo services to approximately 117 destinations in 20 countries; and operates loyalty programs. As of December 31, 2020, it operated a fleet of 297 aircraft, which include 286 passenger aircraft and 11 cargo aircraft; and subleased 3 aircraft comprising 2 passenger aircraft and 1 cargo aircraft to third parties. The company was formerly known as LAN Airlines S.A. and changed its name to LATAM Airlines Group S.A. in June 2012. LATAM Airlines Group S.A. was founded in 1929 and is headquartered in Santiago, Chile. On May 26, 2020, LATAM Airlines Group S.A., along with its affiliates, filed a voluntary petition for reorganization under Chapter 11 in the U.S. Bankruptcy Court for the Southern District of New York.',
#  'city': 'Santiago de Chile',
#  'phone': '56 22 565 2525',
#  'country': 'Chile',
#  'companyOfficers': [],
#  'website': 'https://www.latamairlinesgroup.net',
#  'maxAge': 1,
#  'address1': 'Presidente Riesco 5711',
#  'industry': 'Airlines',
#  'address2': '20th Floor Las Condes',
#  'ebitdaMargins': -0.30203,
#  'profitMargins': -0.76028,
#  'grossMargins': -0.17472,
#  'operatingCashflow': -527195008,
#  'revenueGrowth': 2.151,
#  'operatingMargins': -0.45886,
#  'ebitda': -1134100992,
#  'targetLowPrice': 1180.42,
#  'recommendationKey': 'none',
#  'grossProfits': -589561000,
#  'freeCashflow': 831200000,
#  'targetMedianPrice': 1180.42,
#  'currentPrice': 299.07,
#  'earningsGrowth': None,
#  'currentRatio': 0.225,
#  'returnOnAssets': -0.073249996,
#  'numberOfAnalystOpinions': 1,
#  'targetMeanPrice': 1180.42,
#  'debtToEquity': None,
#  'returnOnEquity': None,
#  'targetHighPrice': 1180.42,
#  'totalCash': 930556032,
#  'totalDebt': 10249829376,
#  'totalRevenue': 3754973952,
#  'totalCashPerShare': 1.535,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 6.192,
#  'quickRatio': 0.163,
#  'recommendationMean': None,
#  'exchange': 'SGO',
#  'shortName': 'LATAM AIRLINES GP',
#  'longName': 'LATAM Airlines Group S.A.',
#  'exchangeTimezoneName': 'America/Santiago',
#  'exchangeTimezoneShortName': 'CLT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-10800000',
#  'quoteType': 'EQUITY',
#  'symbol': 'LTM.SN',
#  'messageBoardId': 'finmb_371065',
#  'market': 'cl_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 52.344,
#  'beta3Year': None,
#  'enterpriseToEbitda': -173.311,
#  '52WeekChange': -0.755921,
#  'morningStarRiskRating': None,
#  'forwardEps': -893.4,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 606408000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': -7.11,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.26072,
#  'netIncomeToCommon': -2854853888,
#  'trailingEps': -4.708,
#  'lastDividendValue': 0.094209,
#  'SandP52WeekChange': 0.14073396,
#  'priceToBook': None,
#  'heldPercentInsiders': 0.59553003,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1632960000,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 258663201,
#  'beta': 2.294247,
#  'enterpriseValue': 196551966720,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': 1590364800,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'priceToSalesTrailing12Months': 48.29819,
#  'dateShortInterest': None,
#  'pegRatio': None,
#  'ytdReturn': None,
#  'forwardPE': -0.33475485,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 312,
#  'regularMarketOpen': 312,
#  'twoHundredDayAverage': 1350.5581,
#  'trailingAnnualDividendYield': 0.00030128204,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 320,
#  'navPrice': None,
#  'averageDailyVolume10Day': 144567,
#  'regularMarketPreviousClose': 312,
#  'fiftyDayAverage': 485.4182,
#  'trailingAnnualDividendRate': 0.094,
#  'open': 312,
#  'toCurrency': None,
#  'averageVolume10days': 144567,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': 1590364800,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 290,
#  'currency': 'CLP',
#  'regularMarketVolume': 904141,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 181358444544,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 220156,
#  'dayLow': 290,
#  'ask': 299.99,
#  'askSize': 0,
#  'volume': 904141,
#  'fiftyTwoWeekHigh': 2200,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 139.99,
#  'bid': 299.79,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 0,
#  'dayHigh': 320,
#  'regularMarketPrice': 299.07,
#  'preMarketPrice': None,
#  'logo_url': 'https://logo.clearbit.com/latamairlinesgroup.net'}

# %%
df_ticker.institutional_holders
# Out:
#                                               Holder   Shares Date Reported  \
# 0  Vanguard International Stock Index-Emerging Ma...  3024840    2021-10-30
# 1  Vanguard International Stock Index-Total Intl ...  1964838    2021-10-30
# 2  Vanguard Intl Equity Index Fds-FTSE All World ...   932195    2021-10-30
# 3  DFA Investment Dimensions-DFA Emerging Mkts Value   736124    2021-10-30
# 4            Cambria ETF Tr-Cambria Global Value ETF   355850    2021-11-29
# 5  Russell Inv Co-Tax-Managed International Equit...   261943    2021-10-30
# 6  Vanguard Intl Equity Index - Total World Stock...   130499    2021-10-30
# 7  Vanguard World Fund-Vanguard ESG International...    46607    2021-08-30
#
#     % Out       Value
# 0  0.0050  3591392532
# 1  0.0032  2332852157
# 2  0.0015  1106795123
# 3  0.0012   874000025
# 4  0.0006    96079500
# 5  0.0004   311004923
# 6  0.0002   154941462
# 7  0.0001    85323434

# %%
df_ticker.recommendations

# %%
df_ticker.actions
# Out:
#              Dividends  Stock Splits
# Date
# 2010-08-16    0.217860           0.0
# 2011-01-10  182.497270           0.0
# 2011-05-16    0.030340           0.0
# 2011-09-12   78.363000           0.0
# 2012-01-09  126.909080           0.0
# 2012-05-14   26.370710           0.0
# 2013-05-13    3.217651           0.0
# 2017-05-15   22.996880           0.0
# 2018-05-10    0.076831           0.0
# 2018-05-14    0.076831           0.0
# 2019-05-13    0.090006           0.0
# 2020-05-25    0.094209           0.0

# %%
df_ticker.quarterly_financials
# Out:
#                                           2021-09-30    2021-06-30  \
# Research Development                            None          None
# Effect Of Accounting Charges                    None          None
# Income Before Tax                       -785144000.0 -1127666000.0
# Minority Interest                        -13872000.0   -10474000.0
# Net Income                              -691873000.0  -769637000.0
# Selling General Administrative           172150000.0   154819000.0
# Gross Profit                             -81141000.0  -193763000.0
# Ebit                                    -480256000.0  -313566000.0
# Operating Income                        -480256000.0  -313566000.0
# Other Operating Expenses                 226965000.0   -35016000.0
# Interest Expense                        -190465000.0  -173609000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# Other Items                                     None          None
# Income Tax Expense                       -90994000.0  -355389000.0
# Total Revenue                           1276019000.0   825853000.0
# Total Operating Expenses                1756275000.0  1139419000.0
# Cost Of Revenue                         1357160000.0  1019616000.0
# Total Other Income Expense Net          -304888000.0  -814100000.0
# Discontinued Operations                         None          None
# Net Income From Continuing Ops          -694150000.0  -772277000.0
# Net Income Applicable To Common Shares  -691873000.0  -769637000.0
#
#                                           2021-03-31    2020-12-31
# Research Development                            None          None
# Effect Of Accounting Charges                    None          None
# Income Before Tax                       -650600000.0 -1218706000.0
# Minority Interest                         -8658000.0    -6672000.0
# Net Income                              -430867000.0  -962477000.0
# Selling General Administrative           148126000.0   255581000.0
# Gross Profit                            -201600000.0  -179555000.0
# Ebit                                    -359380000.0  -569820000.0
# Operating Income                        -359380000.0  -569820000.0
# Other Operating Expenses                   9654000.0   134684000.0
# Interest Expense                        -181091000.0  -176365000.0
# Extraordinary Items                             None          None
# Non Recurring                                   None          None
# Other Items                                     None          None
# Income Tax Expense                      -216929000.0  -254404000.0
# Total Revenue                            842200000.0   810902000.0
# Total Operating Expenses                1201580000.0  1380722000.0
# Cost Of Revenue                         1043800000.0   990457000.0
# Total Other Income Expense Net          -291220000.0  -648886000.0
# Discontinued Operations                         None          None
# Net Income From Continuing Ops          -433671000.0  -964302000.0
# Net Income Applicable To Common Shares  -430867000.0  -962477000.0

# %%
df_ticker.major_holders
# Out:
#         0                                      1
# 0  59.55%        % of Shares Held by All Insider
# 1  26.07%       % of Shares Held by Institutions
# 2  64.46%        % of Float Held by Institutions
# 3      22  Number of Institutions Holding Shares

# %%
df_ticker.balance_sheet
# Out:
#                                     2020-12-31    2019-12-31    2018-12-31  \
# Intangible Assets                 1.046559e+09  1.448241e+09  1.441072e+09
# Total Liab                        1.809248e+10  1.795863e+10  1.663812e+10
# Total Stockholder Equity         -2.435713e+09  3.130782e+09  3.360693e+09
# Minority Interest                -6.672000e+06 -1.605000e+06  7.990800e+07
# Other Current Liab                2.320468e+09  2.906855e+09  2.481659e+09
# Total Assets                      1.565009e+10  2.108781e+10  2.007872e+10
# Common Stock                      3.160718e+09  3.160718e+09  3.160718e+09
# Other Current Assets              4.126530e+08  6.930570e+08  1.827610e+08
# Retained Earnings                -4.193615e+09  3.522720e+08  2.189710e+08
# Other Liab                        2.400363e+09  2.467269e+09  2.346410e+09
# Treasury Stock                   -1.402816e+09 -3.822080e+08 -1.899600e+07
# Other Assets                      7.292310e+08  4.889730e+08  5.654140e+08
# Cash                              1.695841e+09  1.072579e+09  1.081642e+09
# Total Current Liabilities         7.491888e+09  6.960942e+09  5.932249e+09
# Deferred Long Term Asset Charges  5.648160e+08  2.355830e+08  2.735290e+08
# Short Long Term Debt              1.323367e+09  5.359090e+08  6.049680e+08
# Other Stockholder Equity         -1.402638e+09 -3.820300e+08 -1.881800e+07
# Property Plant Equipment          1.073027e+10  1.291962e+10  1.250181e+10
# Total Current Assets              3.143538e+09  4.018228e+09  3.275861e+09
# Long Term Investments             4.930000e+05  3.170000e+06  4.940000e+05
# Net Tangible Assets              -3.482272e+09 -5.270350e+08 -3.744510e+08
# Short Term Investments            3.660000e+05  3.866880e+08  3.238220e+08
# Net Receivables                   7.111040e+08  1.484628e+09  1.388832e+09
# Long Term Debt                    5.045379e+09  4.635694e+09  4.665156e+09
# Inventory                         3.235740e+08  3.542320e+08  2.793440e+08
# Accounts Payable                  2.822640e+08  1.460290e+08  7.578400e+07
# Good Will                                  NaN  2.209576e+09  2.294072e+09
#
#                                     2017-12-31
# Intangible Assets                 1.617247e+09
# Total Liab                        1.453074e+10
# Total Stockholder Equity          4.176089e+09
# Minority Interest                 9.114700e+07
# Other Current Liab                2.852657e+09
# Total Assets                      1.879797e+10
# Common Stock                      3.160718e+09
# Other Current Assets              5.201580e+08
# Retained Earnings                 4.751170e+08
# Other Liab                        2.082514e+09
# Treasury Stock                    5.402540e+08
# Other Assets                      6.968470e+08
# Cash                              1.142004e+09
# Total Current Liabilities         5.842714e+09
# Deferred Long Term Asset Charges  3.640210e+08
# Short Long Term Debt              7.076980e+08
# Other Stockholder Equity          5.404320e+08
# Property Plant Equipment          1.006534e+10
# Total Current Assets              3.745499e+09
# Long Term Investments             4.940000e+05
# Net Tangible Assets              -1.137080e+08
# Short Term Investments            4.736530e+08
# Net Receivables                   1.369905e+09
# Long Term Debt                    5.772544e+09
# Inventory                         2.366660e+08
# Accounts Payable                  1.146900e+08
# Good Will                         2.672550e+09

# %%
df_ticker.calendar
# Out:
#                                     0                    1
# Earnings Date     2020-08-11 00:00:00  2020-08-17 00:00:00
# Earnings Average                 None                 None
# Earnings Low                     None                 None
# Earnings High                    None                 None
# Revenue Average            1802100000           1802100000
# Revenue Low                1802100000           1802100000
# Revenue High               1802100000           1802100000

# %%
df_ticker.sustainability
# Out:
#                                 Value
# 2020-3
# palmOil                         False
# controversialWeapons            False
# gambling                        False
# socialScore                      18.8
# nuclear                         False
# furLeather                      False
# alcoholic                       False
# gmo                             False
# catholic                        False
# socialPercentile                    0
# peerCount                          49
# governanceScore                  7.58
# environmentPercentile               0
# animalTesting                   False
# tobacco                         False
# totalEsg                        36.83
# highestControversy                  2
# esgPerformance               OUT_PERF
# coal                            False
# pesticides                      False
# adult                           False
# percentile                      75.11
# peerGroup              Transportation
# smallArms                       False
# environmentScore                10.45
# governancePercentile                0
# militaryContract                False
